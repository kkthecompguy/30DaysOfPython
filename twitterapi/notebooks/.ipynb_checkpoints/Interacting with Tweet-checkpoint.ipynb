# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "SRKYbF44wb7ImB9c3XxppcX22"
consumer_secret = "GUZpAdVN31FRnD5Tjaxqk5l4tvMlQq6pGl01H7ThhwzVr6yRlV"

# %%
callback_uri = "oob"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
request_url = auth.get_authorization_url()
webbrowser.open(request_url)
user_pin_input = input("What is the user pin? ")
auth.get_access_token(user_pin_input)
# Out:
# What is the user pin? 0160921
# ('933606174812983296-9GM7280599Gt9s0lmrCAXuwGLkyvo4h',
#  'fnGPtm4epsfRBv3wJS6kSlNYC90P0Ijh80Zqzwr0I4MgA')

# %%
api = tweepy.API(auth)

# %%
my_timeline = api.home_timeline()

# %%
columns = set()
allowed_types = [str, int]
tweets_data = []
for status in my_timeline:
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {'user': status.user.screen_name, 'author': status.author.screen_name}
    for k in keys: 
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                columns.add(k)
                single_tweet_data[k] = status_dict[k]
    tweets_data.append(single_tweet_data)
            
header_cols = list(columns)
header_cols.append('user')
header_cols.append('author')

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#                   source  retweet_count quoted_status_id_str  \
# 0  friendly fem tech bot              3                  NaN
# 1  friendly fem tech bot              6                  NaN
# 2  friendly fem tech bot              3                  NaN
# 3        Twitter Web App              0                  NaN
# 4  friendly fem tech bot              1                  NaN
#
#    quoted_status_id                   id                  source_url  \
# 0               NaN  1334144041445945344            https://rike.dev
# 1               NaN  1334143774193283074            https://rike.dev
# 2               NaN  1334143772922433540            https://rike.dev
# 3               NaN  1334143746460561413  https://mobile.twitter.com
# 4               NaN  1334143663199416325            https://rike.dev
#
#                                                 text               id_str  \
# 0  RT @jucktion: Responsive Website Using The Pri...  1334144041445945344
# 1  RT @adahagan: I'm super excited to FINALLY hav...  1334143774193283074
# 2  RT @Tertill_Corp: Congrats @helengreiner Terti...  1334143772922433540
# 3  Banks put on the spot for mimicking ‘rogue’ di...  1334143746460561413
# 4  RT @The_Jo_Knows: Five Jobs In Tech For Women ...  1334143663199416325
#
#   lang  favorite_count            user          author
# 0   en               0        femtech_        femtech_
# 1   en               0        femtech_        femtech_
# 2   en               0        femtech_        femtech_
# 3   en               1  citizentvkenya  citizentvkenya
# 4   en               0        femtech_        femtech_

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {'user': status.user.screen_name, 'author': status.author.screen_name}
        for k in keys: 
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    columns.add(k)
                    single_tweet_data[k] = status_dict[k]
        tweets_data.append(single_tweet_data)

    header_cols = list(columns)
    header_cols.append('user')
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
user = api.get_user('code') 
user_timeline = user.timeline()

# %%
df2 = extract_timeline_as_df(user_timeline)
df2.head()
# Out:
#       source  retweet_count  in_reply_to_status_id quoted_status_id_str  \
# 0     Buffer             31                    NaN                  NaN
# 1     Buffer             13                    NaN                  NaN
# 2     Buffer             18                    NaN                  NaN
# 3  TweetDeck             26                    NaN                  NaN
# 4     Buffer              4                    NaN  1333475002335674368
#
#   in_reply_to_user_id_str  quoted_status_id in_reply_to_status_id_str  \
# 0                     NaN               NaN                       NaN
# 1                     NaN               NaN                       NaN
# 2                     NaN               NaN                       NaN
# 3                     NaN               NaN                       NaN
# 4                     NaN      1.333475e+18                       NaN
#
#                     id                                    source_url  \
# 0  1333852878314803201                            https://buffer.com
# 1  1333815626238980097                            https://buffer.com
# 2  1333546605606293506                            https://buffer.com
# 3  1333540692711370754  https://about.twitter.com/products/tweetdeck
# 4  1333490985200914432                            https://buffer.com
#
#                                                 text               id_str  \
# 0  Are you using WSL? Do you SSH into VMs or use ...  1333852878314803201
# 1  RT @mattbierner: Today's @code tip: managing m...  1333815626238980097
# 2  RT @mattbierner: The latest @code 0 to 20 prov...  1333546605606293506
# 3  RT @jimbobbennett: Did you know you can run @c...  1333540692711370754
# 4   Claudia Regio on Twitter https://t.co/WxY4m6Gie5  1333490985200914432
#
#   in_reply_to_screen_name lang  favorite_count  in_reply_to_user_id  user  \
# 0                     NaN   en             182                  NaN  code
# 1                     NaN   en               0                  NaN  code
# 2                     NaN   en               0                  NaN  code
# 3                     NaN   en               0                  NaN  code
# 4                     NaN   en              42                  NaN  code
#
#   author
# 0   code
# 1   code
# 2   code
# 3   code
# 4   code

# %%
# %%writefile users_timeline.py

import tweepy
import webbrowser
import time
import pandas as pd

consumer_key = "SRKYbF44wb7ImB9c3XxppcX22"
consumer_secret = "GUZpAdVN31FRnD5Tjaxqk5l4tvMlQq6pGl01H7ThhwzVr6yRlV"
callback_uri = "oob"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
request_url = auth.get_authorization_url()
webbrowser.open(request_url)
user_pin_input = input("What is the user pin? ")
auth.get_access_token(user_pin_input)

api = tweepy.API(auth)

def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {'user': status.user.screen_name, 'author': status.author.screen_name}
        for k in keys: 
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    columns.add(k)
                    single_tweet_data[k] = status_dict[k]
        tweets_data.append(single_tweet_data)

    header_cols = list(columns)
    header_cols.append('user')
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

user = api.get_user('code') 
user_timeline = user.timeline()
df2 = extract_timeline_as_df(user_timeline)
df2.head()
# Out:
# Writing users_timeline.py
