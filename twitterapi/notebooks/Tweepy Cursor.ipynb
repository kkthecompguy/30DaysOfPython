# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "SRKYbF44wb7ImB9c3XxppcX22"
consumer_secret = "GUZpAdVN31FRnD5Tjaxqk5l4tvMlQq6pGl01H7ThhwzVr6yRlV"
callback_uri = "oob"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
request_url = auth.get_authorization_url()
webbrowser.open(request_url)
user_pin_input = input("What is the user pin? ")
auth.get_access_token(user_pin_input)
# Out:
# What is the user pin? 1444404
# ('933606174812983296-9GM7280599Gt9s0lmrCAXuwGLkyvo4h',
#  'fnGPtm4epsfRBv3wJS6kSlNYC90P0Ijh80Zqzwr0I4MgA')

# %%
api = tweepy.API(auth)

# %%
for i, status in enumerate(tweepy.Cursor(api.home_timeline).items(50)):
    print(i, status.text)
# Out:
# 0 RT @DaniBat: The main reason the hubs and I own a home is because we're in #STEM fields. Before that it was shitty one bedrooms until we gr…
# 1 RT @GersonRolim: 9 Soft Skills every employee will need in the Age of #AI &amp; #DX
#
# by @BernardMarr via @Forbes @GersonRolim @intellimetri @10…
# 2 RT @WomenTechNet: ⏰ It’s not too late!
#
# 🎫 Get your ticket to the WomenTech Global Awards 2020: https://t.co/3qHITPxPmg
#
# 🎤 Join our inspirin…
# 3 RT @BobSouljaSlim: @CrazyElvo Kuna Kichinjio Ronga😂😂😂ukilock macho na hao watu nyama itabidi ununue
# 4 RT @kwamboqa: Xiaomi Mi 10 Lite 5G  128GB/6GB Ram
# @Ksh.36,999
# +FREE delivery (pay on delivery)
# -0705596611
# •front camera16 MP.
# •battery4160…
# 5 RT @GwisHawaii: #MemberSpotlight! Katie Ackerman  is a Master’s Student in the Department of Atmospheric Sciences! She studies air-sea inte…
# 6 RT @claudiowangu: Two blood cells met and fell in love,
# but
# alas it was all in vein.
# 7 RT @HarbRimah: How secure is your data? 3 predictions and 3 protections in the age of hybrid work https://t.co/HOXDyNiF8Y
#
# #DevOps #DevSec…
# 8 RT @UTCSheffOLP: Rosalind Franklin was a #Chemist whose work was central to the understanding of the molecular structures of DNA.
#
# She stud…
# 9 RT @MicahImaniHall: Congratulations!! 👏🏾👏🏾👏🏾 https://t.co/6vngVaDoHr
# 10 RT @indyjohn: .@BallState Journalism / CICS grad Maria Lee is one of the product managers on the @Chase Mobile app, just named No. 1 in its…
# 11 RT @green4girls: In partnership w/ @SolvayGroup, we are thrilled to launch the Future Innovator's Libray! Packed with educational videos li…
# 12 RT @DianaInitiative: Big thanks to @0x7eff for your $250 donation this #GivingTuesday2020
#
# Want to help support the efforts to increase #e…
# 13 RT @helenevirolan: What a year! Avye has just been announced as the winner of the Women in Tech Aspiring Teen Award
# at the @WomenInTechOrg…
# 14 RT @MirryMish: So happy that politicians have joined the #ShopSmall gang?
#
# We need more voices in power that push for local spending.
#
# If…
# 15 RT @AzraTanovic: Thank you @lswatuk !! (It really is as great as you said it would be😂 I can’t believe I didn’t join sooner!) https://t.co/…
# 16 RT @prevent_ad: Our very own @alexa_pichetb has brilliantly defended her PhD thesis! Alexa has been instrumental in the centre’s work in th…
# 17 RT @girlsintocoding: What a year! Avye has just been announced as the winner of the Women in Tech Aspiring Teen Award
# 27 Nimeshiba bana.
# 28 @DrewMollel 😅😅😅
# 29 RT @254Proff: 💥Adidas and Nike sneakers available at Ksh.3500.
# 📌Sizes 38-45
# 📌☎️:+254708727242 for orders &amp; deliveries.
# 🚛 DELIVERY ACROSS EA…
# 30 RT @254Proff: 💥Nike Air sneakers available at Ksh.3500 only
# 📌Sizes 36-44 available.
# ☎️:+254708727242 for orders &amp; deliveries.
# 🚛 DELIVERY AC…
# 31 RT @ni_honeypot: What do you plan for exams?
# 32 RT @MtuMakali: Huyu tumeanza pillow fight akatoa panga ya kazi mtaani 😅
# 33 RT @yvie_09: Jeez😂😂na si heart hukua na kimbesho
# At this rate mi naona ntatupa yangu , blood nitapump tu electronically🚶‍♀️🚶‍♀️
# 34 RT @LazyMillionire: MY FRIEND'S GIRLFRIEND 😎🍆🍑🔞
#
# SEASON 1🍆🍑🍒🍒🍒
#
# PART 1😎🌹🍒🍒
#      This is gonna be a long story😊so before tuende far, kindly…
# 35 RT @CjayRoddy: Mtu akasirike anitumie pesaya nguo za Christmas 😂
# 36 RT @Karis_jese: Gentlemen don't forget it's bros over hoes.
# Not the other way round.
# 37 RT @ke_pharaoh: Nlikuanga najiuliza mbona remote ya tv haijaandikwa hadi na braille ndio wenye wako blind pia watumie lakini nimeachana nay…
# 38 RT @ke_ghoost: You short people argue because you  won't see the point.
# 39 RT @Iamjeffaustine: Hii handas Juice hukuwa na Taxin ndani??
# Halafu unatema ama unameza
# 40 RT @itsMatador: Safaricom waliacha kuniita Dear, ni kama pia wao walijua mimi ni maskini😭
# 41 RT @jacques_td: Bana cute video in the washrooms is not meant for kenyan gels.... Mnarudi mkinuka mafi ya kale nkt
# 42 RT @Bluesman_kenya: Couple goals https://t.co/14XjGthXp5
# 43 RT @Empiremikee: Besides calculus which other topic was hard in Chemistry🤔🤔🤔🤔
# 44 RT @Karnydaniels: Do you know any guy mwenye alifanya Form 4 between 2014-2019 and is looking for a job?if yes pia mimi najua wengi Sana😆😂
# 45 RT @SmartkidMemes: Gaidi inaamua kudate Dem hajui kukoroga simiti na inaexpect kubuild strong relationship....Tafuta Dem wa mjengo uoe 😂😂🚶🚶🚶
# 46 RT @Its_EricM: Njoroge wa UON nliambiagwa nkusalimie na mamako nkitoka ushago nkiwa first year.... Na urudi ushago wazazi wanalalamika
# 47 RT @_kulandeng: Uzuri wa madem wa ploti ni...unakulanga kamoja kesho kanakuja na marafiki zake😁😁
# 48 RT @crazy_00007: one thing about me i always keep it 1💯✌
# 49 RT @mkebe_ya_asali: Kuna aunty yangu ameniuliza kwanini siwekangi status,ni kama hajui yeye ni family member 😂😂

# %%
cfe_friends_ids = []
for i, _id in enumerate(tweepy.Cursor(api.friends_ids, screen_name='joincfe').items(50)):
    cfe_friends_ids.append(_id)

# %%
query = '#django -JQuery'
for i, status in enumerate(tweepy.Cursor(api.search, q=query).items(50)):
    print(i, status.text, status.author.screen_name)
# Out:
# 0 RT @CouponFreeDisc3: Coupons Free Discount - Creative CSS Animations, Transitions And Transforms Course Courses -&gt; https://t.co/VG6e6sT7k6… JimLynchCodes
# 1 RT @Coupons76: Free Coupons Discount - GraphQL by Example Courses -&gt; https://t.co/HNDXjPRrar
#
# #udemy #100DaysOfCode #webdevelopment #javasc… devvibesbot
# 2 RT @Coupons76: Free Coupons Discount - GraphQL by Example Courses -&gt; https://t.co/HNDXjPRrar
#
# #udemy #100DaysOfCode #webdevelopment #javasc… friday_Js_bot
# 3 RT @Coupons76: Free Coupons Discount - GraphQL by Example Courses -&gt; https://t.co/HNDXjPRrar
#
# #udemy #100DaysOfCode #webdevelopment #javasc… TheDeveloperBot
# 4 RT @Coupons76: Free Coupons Discount - GraphQL by Example Courses -&gt; https://t.co/HNDXjPRrar
#
# #udemy #100DaysOfCode #webdevelopment #javasc… xaelbot
# 5 Free Coupons Discount - GraphQL by Example Courses -&gt; https://t.co/HNDXjPRrar
#
# #udemy #100DaysOfCode… https://t.co/z7Ons28dju Coupons76
# 6 RT @codewithstein: Authentication - Building a time tracking SaaS using Django and Vue - Part 2 https://t.co/ibGTT5Hf5e #django #python #vu… MedTeye
# 7 RT @Flexgigzz_team: Check the top 5 freelancing  jobs  for python programmer,   newbie  friendly (y) (y)
#
# #2020Wrapped #Python  #CareerDev… Rahul_RPandya
# 8 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… CodingNinjaBOT
# 9 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… devvibesbot
# 10 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… codedailybot
# 11 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… codedailybot
# 12 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… codedailybot
# 13 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… codedailybot
# 14 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… codedailybot
# 15 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… twitbot49738436
# 16 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… RobotProud
# 17 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… CodeGnuts
# 18 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… TheDeveloperBot
# 19 RT @DahlitzF: R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support multi-line a… 100xcode
# 20 R6D06
#
# 🚀  Wrote a markdown extension to support bootstrap alerts - this was a painful one as I wanted to support mu… https://t.co/qfJ72yjGWy DahlitzF
# 21 RT @BenchmarkIT_Sol: #Flask is a lightweight, extensible #Python #framework. It is called a #microframework, as it does not provide additio… twitbot49738436
# 22 #Flask is a lightweight, extensible #Python #framework. It is called a #microframework, as it does not provide addi… https://t.co/SSPNxWDBun BenchmarkIT_Sol
# 23 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… Discovertech3
# 24 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… devvibesbot
# 25 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… devvibesbot
# 26 RT @remote_dev_jobs: Senior Full Stack Developer at Nirveda Cognition Inc. #Angular #Application #Automation #CSS #Design #Django #FullStac… CodeGnuts
# 27 RT @remote_dev_jobs: Senior Full Stack Developer at Nirveda Cognition Inc. #Angular #Application #Automation #CSS #Design #Django #FullStac… devvibesbot
# 28 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… _reactdev
# 29 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… CodeGnuts
# 30 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… php_synopsis
# 31 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… js_bits
# 32 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… CodeGnuts
# 33 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… JimLynchCodes
# 34 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… ImNickHuber
# 35 RT @CouponOnlineCo3: Courses Free Discount - Complete Web Development Course: HTML, Vue.js, PHP, MySQL  -&gt; https://t.co/2iO6d6Hslm
#
# #udemy… api_learnn
# 36 RT @remote_dev_jobs: Senior Full Stack Developer at Nirveda Cognition Inc. #Angular #Application #Automation #CSS #Design #Django #FullStac… friday_Js_bot
# 37 RT @remote_dev_jobs: Senior Full Stack Developer at Nirveda Cognition Inc. #Angular #Application #Automation #CSS #Design #Django #FullStac… remote_dev_job
# 38 Senior Full Stack Developer at Nirveda Cognition Inc. #Angular #Application #Automation #CSS #Design #Django… https://t.co/cLZIaclXzF remote_dev_jobs
# 39 RT @Eli_Krumova: #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML #MachineLearnin… newbie_codes
# 40 RT @Eli_Krumova: #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML #MachineLearnin… 30xcodes
# 41 RT @Eli_Krumova: #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML #MachineLearnin… bot_flutter
# 42 As a #Django programmer I cannot praise The Django Extensions package enough. Do yourself a favor and check it out… https://t.co/d0eTocZcNa diek007
# 43 RT @Eli_Krumova: #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML #MachineLearnin… fluttbot
# 44 RT @Eli_Krumova: #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML #MachineLearnin… ServerlessFan
# 45 #Django:
# Django Girls #Tutorial - #Python Introduction
# ⬇️
# https://t.co/Kv2yRUC02G
# Via @SourabhSKatoch
#
# #ML… https://t.co/kb998neGIF Eli_Krumova
# 46 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… DevHighlights
# 47 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… xaelbot
# 48 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… nlognbot
# 49 RT @CouponOnlineCo3: Courses Free Discount - Javascript Tutorial and Projects Course  -&gt; https://t.co/LcFpPJNY7j
#
# #udemy #coupons #100DaysO… AaronCuddeback

# %%
def handle_limit(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            # send email, webhook, logs
            time.sleep(15 * 60)

# %%
# %%writefile tweepy_cursor.py

import tweepy
import webbrowser
import time
import pandas as pd

consumer_key = "SRKYbF44wb7ImB9c3XxppcX22"
consumer_secret = "GUZpAdVN31FRnD5Tjaxqk5l4tvMlQq6pGl01H7ThhwzVr6yRlV"
callback_uri = "oob"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
request_url = auth.get_authorization_url()
webbrowser.open(request_url)
user_pin_input = input("What is the user pin? ")
auth.get_access_token(user_pin_input)

api = tweepy.API(auth) 

for i, status in enumerate(tweepy.Cursor(api.home_timeline).items(50)):
    print(i, status.text)

for i, status in enumerate(tweepy.Cursor(api.user_timeline, screen_name='crazyelvo').items(50)):
print(i, status.text)

cfe_friends_ids = []
for i, _id in enumerate(tweepy.Cursor(api.friends_ids, screen_name='joincfe').items(50)):
    cfe_friends_ids.append(_id)
    
query = '#django -JQuery'
for i, status in enumerate(tweepy.Cursor(api.search, q=query).items(50)):
    print(i, status.text, status.author.screen_name)
    

def handle_limit(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            # send email, webhook, logs
            time.sleep(15 * 60)
for i, status in enumerate(handle_limit(tweepy.Cursor(api.search, q=query).items(50))):
# Out:
# Writing tweepy_cursor.py
