# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'movies')
CACHE = os.path.join(BASE_DIR, 'cache')
dataset = os.path.join(CACHE, 'themoviedb-search.csv') 
output_file = os.path.join(CACHE, 'themoviedb-dataset-cleaned.csv')

# %%
df = pd.read_csv(dataset)
df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /p9JcAhM62U7exDGrSVqeITjlAsf.jpg
# 1  False  /igO0gR0KyGv4LtU4xTOx1TBMaFM.jpg
# 2  False  /7W8SYHJaYA0dIc9tyx9RMiRUVGg.jpg
# 3  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  False  /vScBqbDYn95Az8SvNoYKGvFFVmy.jpg
#
#                                belongs_to_collection     budget  \
# 0                                                NaN          0
# 1                                                NaN          0
# 2                                                NaN          0
# 3  {'id': 86311, 'name': 'The Avengers Collection...  356000000
# 4                                                NaN          0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 1                                                 []
# 2                [{'id': 99, 'name': 'Documentary'}]
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# ...

# %%
df.drop(['backdrop_path', 'belongs_to_collection', 'genres', 'homepage', 'original_title', 'runtime', 'spoken_languages', 'poster_path', 'production_companies', 'production_countries'], axis=1, inplace=True)
df.head()
# Out:
#    adult     budget      id     imdb_id original_language  \
# 0  False          0  586592   tt8816194                en
# 1  False          0  691329         NaN                en
# 2  False          0   18312   tt1135489                en
# 3  False  356000000  299534   tt4154796                en
# 4  False          0  720914  tt12292428                en
#
#                                             overview  popularity release_date  \
# 0  After receiving a cryptic letter from his estr...      18.766   2019-09-05
# 1  Hamm is an ageing, blind tyrant who is confine...       3.367   2020-04-01
# 2  For the New World Order (NWO), a world governm...       4.266   2007-11-01
# 3  After the devastating events of Avengers: Infi...     235.886   2019-04-24
# 4  What will the future be like in the year 2050?...       3.188   2020-05-19
#
#       revenue    status                                            tagline  \
# ...

# %%
df = df.sort_values(by='popularity', ascending=False)
df.head()
# Out:
#     adult     budget      id    imdb_id original_language  \
# 3   False  356000000  299534  tt4154796                en
# 37  False   63000000     603  tt0133093                en
# 40  False  150000000     604  tt0234215                en
# 39  False  150000000     605  tt0242653                en
# 0   False          0  586592  tt8816194                en
#
#                                              overview  popularity  \
# 3   After the devastating events of Avengers: Infi...     235.886
# 37  Set in the 22nd century, The Matrix tells the ...      60.168
# 40  Six months after the events depicted in The Ma...      47.752
# 39  The human city of Zion defends itself against ...      35.021
# 0   After receiving a cryptic letter from his estr...      18.766
#
#    release_date     revenue    status  \
# 3    2019-04-24  2797800564  Released
# 37   1999-03-30   463517383  Released
# 40   2003-05-15   738599701  Released
# 39   2003-11-03   424988211  Released
# ...

# %%
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#    adult     budget      id    imdb_id original_language  \
# 0  False  356000000  299534  tt4154796                en
# 1  False   63000000     603  tt0133093                en
# 2  False  150000000     604  tt0234215                en
# 3  False  150000000     605  tt0242653                en
# 4  False          0  586592  tt8816194                en
#
#                                             overview  popularity release_date  \
# 0  After the devastating events of Avengers: Infi...     235.886   2019-04-24
# 1  Set in the 22nd century, The Matrix tells the ...      60.168   1999-03-30
# 2  Six months after the events depicted in The Ma...      47.752   2003-05-15
# 3  The human city of Zion defends itself against ...      35.021   2003-11-03
# 4  After receiving a cryptic letter from his estr...      18.766   2019-09-05
#
#       revenue    status                                            tagline  \
# ...

# %%
df.to_csv(output_file, index=False)
